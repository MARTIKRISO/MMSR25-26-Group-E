# %% [markdown]
# # Late Fusion - Reciprocal Rank Fusion (RRF)

# %%
import os, sys
from tqdm import tqdm

target_folder = 'MMSR25-26-Group-E'
current_path = os.getcwd()

while os.path.basename(current_path) != target_folder:
    if os.path.basename(current_path) == 'RetrievalAlgorithm':
        if os.path.join(current_path) not in sys.path:
            sys.path.append(os.path.join(current_path))
    parent = os.path.dirname(current_path)
    os.chdir(parent)
    current_path = parent
print('Current path:',  os.getcwd())

from RetrievalAlgorithm.src.utils.data_loading import load_parquet_files_from_dir
from RetrievalAlgorithm.src.multimodal_late_fusion_calculations import calculate_late_fusion_rrf_scores
# Out:
# Current path: D:\University\7th_Semester\MMSR25-26-Group-E

# %% [markdown]
# ## Calculate RRF Scores

# %%
norm_names = ['max_abs', 'min_max', 'raw', 'robust', 'standard']
sim_scores_df_list = []

for norm_name in norm_names:
    print('='*100)
    print('Norm name:', norm_name)

    unimodal_scores_dfs_dict = load_parquet_files_from_dir(parquet_target_dir=f'RetrievalAlgorithm/results/unimodal/{norm_name}')

    audio_df = unimodal_scores_dfs_dict[f'unimodal_{norm_name}_audio_similarity_scores.parquet']
    lyrics_df = unimodal_scores_dfs_dict[f'unimodal_{norm_name}_lyrics_similarity_scores.parquet']
    video_df = unimodal_scores_dfs_dict[f'unimodal_{norm_name}_video_similarity_scores.parquet']

    unimodal_score_dfs = [audio_df, lyrics_df, video_df]
    sim_scores_df_list.append((norm_name,  calculate_late_fusion_rrf_scores(score_dfs=unimodal_score_dfs, k=60)))
# Out:
# ====================================================================================================
# Norm name: raw
# Loading Parquet Files: 100%|██████████| 3/3 [00:00<00:00, 32017.59it/s]
# Ordering ids in DataFrames: 100%|██████████| 3/3 [00:14<00:00,  4.87s/it]
# Merging score DataFrames: 2it [00:13,  6.97s/it]
# Normalizing numerical columns: 100%|██████████| 3/3 [00:00<00:00,  6.37it/s]
# 8605026
# 8600878
# Col: score_0
# 17205904
# query           False
# target          False
# score_0         False
# score_1         False
# score           False
# score_0_rank    False
# dtype: bool
# Col: score_1
# 17205904
# query           False
# target          False
# score_0         False
# score_1         False
# score           False
# score_0_rank    False
# score_1_rank    False
# dtype: bool
# Col: score
# 17205904
# query           False
# target          False
# score_0         False
# score_1         False
# score           False
# score_0_rank    False
# score_1_rank    False
# score_rank      False
# dtype: bool
# ====================================================================================================
# Norm name: min_max
# Loading Parquet Files: 100%|██████████| 3/3 [00:00<00:00, 15458.12it/s]
# Ordering ids in DataFrames: 100%|██████████| 3/3 [00:14<00:00,  4.88s/it]
# Merging score DataFrames: 2it [00:13,  6.90s/it]
# Normalizing numerical columns: 100%|██████████| 3/3 [00:00<00:00,  5.23it/s]
# 8605026
# 8600878
# Col: score_0
# 17205904
# query           False
# target          False
# score_0         False
# score_1         False
# score            True
# score_0_rank    False
# dtype: bool
# Col: score_1
# 17205904
# query           False
# target          False
# score_0         False
# score_1         False
# score            True
# score_0_rank    False
# score_1_rank    False
# dtype: bool
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[2], line 15
#      12 video_df = unimodal_scores_dfs_dict[f'unimodal_{norm_name}_video_similarity_scores.parquet']
#      14 unimodal_score_dfs = [audio_df, lyrics_df, video_df]
# ---> 15 sim_scores_df_list.append((norm_name,  calculate_late_fusion_rrf_scores(score_dfs=unimodal_score_dfs, k=60)))
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\RetrievalAlgorithm\src\multimodal_late_fusion_calculations.py:47, in calculate_late_fusion_rrf_scores(score_dfs, k)
#      44 combined_df = _combine_score_dfs(score_dfs=score_dfs)
#      45 standard_df = _standardize_df(df=combined_df)
# ---> 47 ranked_pairs_df = _get_rank_pairs_df(scores_df=standard_df)
#      49 rrf_result_df = ranked_pairs_df[['query', 'target']].copy()
#      50 rrf_result_df['score'] = (1 / (k + rrf_result_df.filter(like='_rank'))).sum(axis=1)
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\RetrievalAlgorithm\src\multimodal_late_fusion_calculations.py:34, in _get_rank_pairs_df(scores_df)
#      28 score_cols = df.select_dtypes(include='number').columns
#      30 for col in score_cols:
#      31     df[f'{col}_rank'] = (
#      32         df.groupby('query')[col]
#      33           .rank(method='first', ascending=False)
# ---> 34           .astype('int32')
#      35                   - 1
#      36     )
#      37     print('Col:', col)
#      38     print(len(df))
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File D:\University\7th_Semester\MMSR25-26-Group-E\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# ## Save results

# %%
target_dir = 'RetrievalAlgorithm/results/multimodal/late_fusion/rrf'
os.makedirs(target_dir, exist_ok=True)

for norm_name, sim_scores_df in tqdm(sim_scores_df_list, desc='Saving similarity scores'):
    os.makedirs(target_dir, exist_ok=True)
    output_path = os.path.join(target_dir, f'multimodal_{norm_name}_rrf_similarity_scores.parquet')
    sim_scores_df.to_parquet(output_path, index=False)

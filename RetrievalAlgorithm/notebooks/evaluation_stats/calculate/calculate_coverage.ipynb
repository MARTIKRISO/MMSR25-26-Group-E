# %% [markdown]
# # Evaluation (Coverage)

# %%
import os, sys
import pandas as pd
from tqdm import tqdm
from typing import Dict

target_folder = 'MMSR25-26-Group-E'
current_path = os.getcwd()

while os.path.basename(current_path) != target_folder:
    if os.path.basename(current_path) == 'RetrievalAlgorithm':
        if os.path.join(current_path) not in sys.path:
            sys.path.append(os.path.join(current_path))
    parent = os.path.dirname(current_path)
    os.chdir(parent)
    current_path = parent
print(current_path)


from EvaluationMetrics.src.data_loader import load_songs_data, get_genre_columns
from EvaluationMetrics.src.metrics import coverage_at_k
from RetrievalAlgorithm.src.utils.all_queries_metrics_evaluation import _calculate_and_save_unimodal_metric, _calculate_and_save_multimodal_metric, _calculate_and_save_rrf_metric, _calculate_and_save_multimodal_max_score_metric, _calculate_and_save_nn_based_metric
# Out:
# D:\University\7th_Semester\multimedia_search_and_retrieval\MMSR25-26-Group-E

# %%
norm_names = ['max_abs', 'min_max', 'raw', 'robust', 'standard']
eval_songs_df = load_songs_data()
genres_columns = get_genre_columns()

# %% [markdown]
# ## Calculate MRR for each Track

# %%
metric_at_k_name = 'Coverage'
metric_at_k = coverage_at_k

# %% [markdown]
# ### Unimodal

# %% [markdown]
# #### Lyrics (BERT embeddings)

# %%
_calculate_and_save_unimodal_metric(
    feature_name='lyrics',
    target_dir='RetrievalAlgorithm/results/unimodal',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# ====================================================================================================
# Normalization Name: raw
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5:   0%|          | 0/4148 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Miro\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\process.py", line 254, in _process_worker
#     r = call_item.fn(*call_item.args, **call_item.kwargs)
#   File "D:\University\7th_Semester\multimedia_search_and_retrieval\MMSR25-26-Group-E\RetrievalAlgorithm\src\utils\per_query_metrics_evaluation.py", line 60, in _eval_single_query
#     metric_at_k(
#     ~~~~~~~~~~~^
#         query_id=query_id,
#         ^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         genre_columns=genres_columns
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
# TypeError: coverage_at_k() got an unexpected keyword argument 'query_id'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 _calculate_and_save_unimodal_metric(
#       2     feature_name='lyrics',
#       3     target_dir='RetrievalAlgorithm/results/unimodal',
#       4     eval_songs_df=eval_songs_df,
#       5     genres_columns=genres_columns,
#       6     metric_at_k=metric_at_k,
#       7     metric_at_k_name=metric_at_k_name,
#       8 )
#
# File D:\University\7th_Semester\multimedia_search_and_retrieval\MMSR25-26-Group-E\RetrievalAlgorithm\src\utils\all_queries_metrics_evaluation.py:38, in _calculate_and_save_unimodal_metric(feature_name, target_dir, eval_songs_df, genres_columns, metric_at_k, metric_at_k_name)
#      35 print('='*100)
#      36 print('Normalization Name:', norm_name, '\n')
# ---> 38 eval_score_df = get_eval_metrics_for_each_query(
#      39     scores_df=precalculated_scores_df,
#      40     k_range=[5, 10, 20, 50, 100, 200],
#      41     genres_columns=genres_columns,
#      42     eval_songs_df=eval_songs_df,
#      43     metric_at_k=metric_at_k
#      44 )
#      45 os.makedirs(output_norm_dir, exist_ok=True)
#      47 eval_score_df.to_parquet(output_path, index=False)
#
# File D:\University\7th_Semester\multimedia_search_and_retrieval\MMSR25-26-Group-E\RetrievalAlgorithm\src\utils\per_query_metrics_evaluation.py:117, in get_eval_metrics_for_each_query(scores_df, k_range, eval_songs_df, genres_columns, metric_at_k, n_jobs)
#     110     futures = [executor.submit(_eval_single_query, t) for t in tasks]
#     112     for future in tqdm(
#     113         as_completed(futures),
#     114         total=len(futures),
#     115         desc=f'Evaluated Tracks at k={k}'
#     116     ):
# --> 117         query_id, score = future.result()
#     118         results[query_id] = score
#     120 result_indices_dfs.append(
#     121     pd.DataFrame(list(results.items()), columns=['query_id', f'@k{k}'])
#     122 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# TypeError: coverage_at_k() got an unexpected keyword argument 'query_id'

# %% [markdown]
# #### Audio (MFCC)

# %%
_calculate_and_save_unimodal_metric(
    feature_name='audio',
    target_dir='RetrievalAlgorithm/results/unimodal',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# #### Videoclip (VGG19)

# %%
_calculate_and_save_unimodal_metric(
    feature_name='video',
    target_dir='RetrievalAlgorithm/results/unimodal',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# ### Multimodal (Early Fusion)

# %% [markdown]
# #### Audio + Videoclips

# %%
_calculate_and_save_multimodal_metric(
    feature_name='audio_videoclips',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# #### Lyrics + Audio

# %%
_calculate_and_save_multimodal_metric(
    feature_name='lyrics_audio',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# #### Lyrics + Videoclips

# %%
_calculate_and_save_multimodal_metric(
    feature_name='lyrics_videoclips',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# #### Lyrics + Audio + Videoclips

# %%
_calculate_and_save_multimodal_metric(
    feature_name='lyrics_audio_videoclips',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# ### Multimodal (Late Fusion)

# %% [markdown]
# #### Max Score

# %%
_calculate_and_save_multimodal_max_score_metric(
    target_dir='RetrievalAlgorithm/results/multimodal/late_fusion/max_score',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# ### RRF

# %%
_calculate_and_save_rrf_metric(
    target_dir='RetrievalAlgorithm/results/multimodal/late_fusion/rrf',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

# %% [markdown]
# ## NN-based

# %%
_calculate_and_save_nn_based_metric(
    target_dir='RetrievalAlgorithm/results/NN-based/pretrained',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)

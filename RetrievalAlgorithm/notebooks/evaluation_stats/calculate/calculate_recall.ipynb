# %% [markdown]
# # Evaluation (Recall)

# %%
import os, sys
import pandas as pd
from tqdm import tqdm
from typing import Dict

target_folder = 'MMSR25-26-Group-E'
current_path = os.getcwd()

while os.path.basename(current_path) != target_folder:
    if os.path.basename(current_path) == 'RetrievalAlgorithm':
        if os.path.join(current_path) not in sys.path:
            sys.path.append(os.path.join(current_path))
    parent = os.path.dirname(current_path)
    os.chdir(parent)
    current_path = parent
print(current_path)


from EvaluationMetrics.src.data_loader import load_songs_data, get_genre_columns
from EvaluationMetrics.src.metrics import recall_at_k
from RetrievalAlgorithm.src.utils.all_queries_metrics_evaluation import _calculate_and_save_unimodal_metric, _calculate_and_save_multimodal_metric, _calculate_and_save_rrf_metric, _calculate_and_save_multimodal_max_score_metric, _calculate_and_save_nn_based_metric
# Out:
# D:\University\7th_Semester\multimedia_search_and_retrieval\MMSR25-26-Group-E

# %%
norm_names = ['max_abs', 'min_max', 'raw', 'robust', 'standard']
eval_songs_df = load_songs_data()
genres_columns = get_genre_columns()

# %% [markdown]
# ## Calculate Recall for each Track

# %%
metric_at_k_name = 'recall'
metric_at_k = recall_at_k

# %% [markdown]
# ### Unimodal

# %% [markdown]
# #### Lyrics (BERT embeddings)

# %%
_calculate_and_save_unimodal_metric(
    feature_name='lyrics',
    target_dir='RetrievalAlgorithm/results/unimodal',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# #### Audio (MFCC)

# %%
_calculate_and_save_unimodal_metric(
    feature_name='audio',
    target_dir='RetrievalAlgorithm/results/unimodal',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# #### Videoclip (VGG19)

# %%
_calculate_and_save_unimodal_metric(
    feature_name='video',
    target_dir='RetrievalAlgorithm/results/unimodal',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# ### Multimodal (Early Fusion)

# %% [markdown]
# #### Audio + Videoclips

# %%
_calculate_and_save_multimodal_metric(
    feature_name='audio_videoclips',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# #### Lyrics + Audio

# %%
_calculate_and_save_multimodal_metric(
    feature_name='lyrics_audio',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# #### Lyrics + Videoclips

# %%
_calculate_and_save_multimodal_metric(
    feature_name='lyrics_videoclips',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# #### Lyrics + Audio + Videoclips

# %%
_calculate_and_save_multimodal_metric(
    feature_name='lyrics_audio_videoclips',
    target_dir='RetrievalAlgorithm/results/multimodal/early_fusion',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# ### Multimodal (Late Fusion)

# %% [markdown]
# #### Max Score

# %%
_calculate_and_save_multimodal_max_score_metric(
    target_dir='RetrievalAlgorithm/results/multimodal/late_fusion/max_score',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Loading Max Score precalculated similarity scores ...
# Loading precalculated scores: 100%|██████████| 5/5 [00:00<00:00, 1930.72it/s]
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# ### RRF

# %%
_calculate_and_save_rrf_metric(
    target_dir='RetrievalAlgorithm/results/multimodal/late_fusion/rrf',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Loading RRF similarity scores ...
# Skipping raw
# Skipping min_max
# Skipping max_abs
# Skipping robust
# Skipping standard

# %% [markdown]
# ## NN-based

# %%
_calculate_and_save_nn_based_metric(
    target_dir='RetrievalAlgorithm/results/NN-based/pretrained',
    eval_songs_df=eval_songs_df,
    genres_columns=genres_columns,
    metric_at_k=metric_at_k,
    metric_at_k_name=metric_at_k_name,
)
# Out:
# Loading NN-based similarity scores ...
# ====================================================================================================
# Variation Name: max_scores
# Skipping max_scores/lyrics_bert_lyrics_bert_padding
# Skipping max_scores/lyrics_bert_mfcc_bow_padding
# Skipping max_scores/mfcc_bow_mfcc_bow_padding
# Skipping max_scores/vgg19_lyrics_bert_padding
# Skipping max_scores/vgg19_mfcc_bow_padding
# ----------------------------------------------------------------------------------------------------
# Feature Name: vgg19_vgg19_padding
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5: 100%|██████████| 4148/4148 [05:19<00:00, 12.97it/s]
# ----------------------------------------------------------------------------------------------------
# k = 10
# Evaluated Tracks at k=10: 100%|██████████| 4148/4148 [04:58<00:00, 13.88it/s]
# ----------------------------------------------------------------------------------------------------
# k = 20
# Evaluated Tracks at k=20: 100%|██████████| 4148/4148 [04:41<00:00, 14.76it/s]
# ----------------------------------------------------------------------------------------------------
# k = 50
# Evaluated Tracks at k=50: 100%|██████████| 4148/4148 [04:31<00:00, 15.30it/s]
# ----------------------------------------------------------------------------------------------------
# k = 100
# Evaluated Tracks at k=100: 100%|██████████| 4148/4148 [04:18<00:00, 16.06it/s]
# ----------------------------------------------------------------------------------------------------
# k = 200
# Evaluated Tracks at k=200: 100%|██████████| 4148/4148 [07:21<00:00,  9.40it/s]
# ====================================================================================================
# Variation Name: avg_scores
# ----------------------------------------------------------------------------------------------------
# Feature Name: lyrics_bert_lyrics_bert_padding
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5: 100%|██████████| 4148/4148 [02:48<00:00, 24.60it/s]
# ----------------------------------------------------------------------------------------------------
# k = 10
# Evaluated Tracks at k=10: 100%|██████████| 4148/4148 [02:50<00:00, 24.38it/s]
# ----------------------------------------------------------------------------------------------------
# k = 20
# Evaluated Tracks at k=20: 100%|██████████| 4148/4148 [03:16<00:00, 21.10it/s]
# ----------------------------------------------------------------------------------------------------
# k = 50
# Evaluated Tracks at k=50: 100%|██████████| 4148/4148 [03:54<00:00, 17.65it/s]
# ----------------------------------------------------------------------------------------------------
# k = 100
# Evaluated Tracks at k=100: 100%|██████████| 4148/4148 [04:45<00:00, 14.51it/s]
# ----------------------------------------------------------------------------------------------------
# k = 200
# Evaluated Tracks at k=200: 100%|██████████| 4148/4148 [07:14<00:00,  9.55it/s]
# ----------------------------------------------------------------------------------------------------
# Feature Name: lyrics_bert_mfcc_bow_padding
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5: 100%|██████████| 4148/4148 [02:46<00:00, 24.98it/s]
# ----------------------------------------------------------------------------------------------------
# k = 10
# Evaluated Tracks at k=10: 100%|██████████| 4148/4148 [02:51<00:00, 24.17it/s]
# ----------------------------------------------------------------------------------------------------
# k = 20
# Evaluated Tracks at k=20: 100%|██████████| 4148/4148 [02:51<00:00, 24.21it/s]
# ----------------------------------------------------------------------------------------------------
# k = 50
# Evaluated Tracks at k=50: 100%|██████████| 4148/4148 [03:25<00:00, 20.20it/s]
# ----------------------------------------------------------------------------------------------------
# k = 100
# Evaluated Tracks at k=100: 100%|██████████| 4148/4148 [04:54<00:00, 14.11it/s]
# ----------------------------------------------------------------------------------------------------
# k = 200
# Evaluated Tracks at k=200: 100%|██████████| 4148/4148 [07:06<00:00,  9.73it/s]
# ----------------------------------------------------------------------------------------------------
# Feature Name: mfcc_bow_mfcc_bow_padding
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5: 100%|██████████| 4148/4148 [02:47<00:00, 24.78it/s]
# ----------------------------------------------------------------------------------------------------
# k = 10
# Evaluated Tracks at k=10: 100%|██████████| 4148/4148 [02:50<00:00, 24.31it/s]
# ----------------------------------------------------------------------------------------------------
# k = 20
# Evaluated Tracks at k=20: 100%|██████████| 4148/4148 [02:54<00:00, 23.82it/s]
# ----------------------------------------------------------------------------------------------------
# k = 50
# Evaluated Tracks at k=50: 100%|██████████| 4148/4148 [03:28<00:00, 19.92it/s]
# ----------------------------------------------------------------------------------------------------
# k = 100
# Evaluated Tracks at k=100: 100%|██████████| 4148/4148 [04:35<00:00, 15.04it/s]
# ----------------------------------------------------------------------------------------------------
# k = 200
# Evaluated Tracks at k=200: 100%|██████████| 4148/4148 [07:16<00:00,  9.51it/s]
# ----------------------------------------------------------------------------------------------------
# Feature Name: vgg19_lyrics_bert_padding
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5: 100%|██████████| 4148/4148 [02:52<00:00, 23.98it/s]
# ----------------------------------------------------------------------------------------------------
# k = 10
# Evaluated Tracks at k=10: 100%|██████████| 4148/4148 [02:50<00:00, 24.27it/s]
# ----------------------------------------------------------------------------------------------------
# k = 20
# Evaluated Tracks at k=20: 100%|██████████| 4148/4148 [02:57<00:00, 23.42it/s]
# ----------------------------------------------------------------------------------------------------
# k = 50
# Evaluated Tracks at k=50: 100%|██████████| 4148/4148 [03:38<00:00, 18.98it/s]
# ----------------------------------------------------------------------------------------------------
# k = 100
# Evaluated Tracks at k=100: 100%|██████████| 4148/4148 [04:35<00:00, 15.05it/s]
# ----------------------------------------------------------------------------------------------------
# k = 200
# Evaluated Tracks at k=200: 100%|██████████| 4148/4148 [07:15<00:00,  9.53it/s]
# ----------------------------------------------------------------------------------------------------
# Feature Name: vgg19_mfcc_bow_padding
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5: 100%|██████████| 4148/4148 [02:50<00:00, 24.32it/s]
# ----------------------------------------------------------------------------------------------------
# k = 10
# Evaluated Tracks at k=10: 100%|██████████| 4148/4148 [02:52<00:00, 24.02it/s]
# ----------------------------------------------------------------------------------------------------
# k = 20
# Evaluated Tracks at k=20: 100%|██████████| 4148/4148 [03:12<00:00, 21.55it/s]
# ----------------------------------------------------------------------------------------------------
# k = 50
# Evaluated Tracks at k=50: 100%|██████████| 4148/4148 [03:34<00:00, 19.37it/s]
# ----------------------------------------------------------------------------------------------------
# k = 100
# Evaluated Tracks at k=100: 100%|██████████| 4148/4148 [04:34<00:00, 15.12it/s]
# ----------------------------------------------------------------------------------------------------
# k = 200
# Evaluated Tracks at k=200: 100%|██████████| 4148/4148 [07:41<00:00,  8.99it/s]
# ----------------------------------------------------------------------------------------------------
# Feature Name: vgg19_vgg19_padding
#
# ----------------------------------------------------------------------------------------------------
# k = 5
# Evaluated Tracks at k=5: 100%|██████████| 4148/4148 [03:04<00:00, 22.50it/s]
# ----------------------------------------------------------------------------------------------------
# k = 10
# Evaluated Tracks at k=10: 100%|██████████| 4148/4148 [03:05<00:00, 22.41it/s]
# ----------------------------------------------------------------------------------------------------
# k = 20
# Evaluated Tracks at k=20: 100%|██████████| 4148/4148 [03:10<00:00, 21.78it/s]
# ----------------------------------------------------------------------------------------------------
# k = 50
# Evaluated Tracks at k=50: 100%|██████████| 4148/4148 [03:30<00:00, 19.74it/s]
# ----------------------------------------------------------------------------------------------------
# k = 100
# Evaluated Tracks at k=100: 100%|██████████| 4148/4148 [04:49<00:00, 14.32it/s]
# ----------------------------------------------------------------------------------------------------
# k = 200
# Evaluated Tracks at k=200: 100%|██████████| 4148/4148 [07:01<00:00,  9.83it/s]

# %%
import main

# %%
# Out:
# Loaded

# %%
main.DFS
# Out:
# {}

# %%
tr, data = main.load_data()
# Out:
# Loaded

# %%
data["multimodal"]
# Out:
# {'unimodal': {'max_abs': {'unimodal_max_abs_audio_similarity_scores.parquet':                      id_1              id_2     score
#    0        o5CwFepK9xTbBU5I  o5CwFepK9xTbBU5I  1.000000
#    1        o5CwFepK9xTbBU5I  o5D1rlazYd9bCBlI  0.871973
#    2        o5CwFepK9xTbBU5I  qcUvs7BssXOWyJET  0.895640
#    3        o5CwFepK9xTbBU5I  meMXtRJMnRgPV4Gt  0.850832
#    4        o5CwFepK9xTbBU5I  Bz8Ut1ZVZhWnvoMo  0.860594
#    ...                   ...               ...       ...
#    8605021  7OsxMDcFbqdMHXN0  dAVSHlWNfvQTLyU7  0.849477
#    8605022  7OsxMDcFbqdMHXN0  GRlCQYNd17jNgAtf  0.861853
#    8605023  dAVSHlWNfvQTLyU7  dAVSHlWNfvQTLyU7  1.000000
#    8605024  dAVSHlWNfvQTLyU7  GRlCQYNd17jNgAtf  0.848654
#    8605025  GRlCQYNd17jNgAtf  GRlCQYNd17jNgAtf  1.000000
#
#    [8605026 rows x 3 columns],
#    'unimodal_max_abs_lyrics_similarity_scores.parquet':                      id_1              id_2     score
#    0        h48f46ZsT9h0Z5Dm  h48f46ZsT9h0Z5Dm  1.000000
# ...
